# %% [markdown]
# # College Majors
#
# ## Introduction to the College Majors Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

recent_grads = pd.read_csv("recent-grads.csv")
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# Low_wage_jobs                             193
# Name: 0, dtype: object

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# 0      ...              270                  1207          37
# 1      ...              170                   388          85
# 2      ...              133                   340          16
# 3      ...              150                   692          40
# 4      ...             5180                 16697        1672
#
#    Unemployment_rate  Median  P25th   P75th  College_jobs  Non_college_jobs  \
# 0           0.018381  110000  95000  125000          1534               364
# 1           0.117241   75000  55000   90000           350               257
# 2           0.024096   73000  50000  105000           456               176
# 3           0.050125   70000  43000   80000           529               102
# 4           0.061098   65000  50000   75000         18314              4440
#
#    Low_wage_jobs
# 0            193
# 1             50
# 2              0
# 3              0
# 4            972
#
# [5 rows x 21 columns]

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# std      0.231205   618.361022   50675.002241   42869.655092   14648.179473
# min      0.000000     2.000000       0.000000     111.000000       0.000000
# 25%      0.336026    39.000000    3608.000000    3154.000000    1030.000000
# 50%      0.534024   130.000000   11797.000000   10048.000000    3299.000000
# 75%      0.703299   338.000000   31433.000000   25147.000000    9948.000000
# max      0.968954  4212.000000  307933.000000  251540.000000  115172.000000
#
#        Full_time_year_round    Unemployed  Unemployment_rate         Median  \
# count            173.000000    173.000000         173.000000     173.000000
# mean           19694.427746   2416.329480           0.068191   40151.445087
# std            33160.941514   4112.803148           0.030331   11470.181802
# min              111.000000      0.000000           0.000000   22000.000000
# 25%             2453.000000    304.000000           0.050306   33000.000000
# 50%             7413.000000    893.000000           0.067961   36000.000000
# 75%            16891.000000   2393.000000           0.087557   45000.000000
# max           199897.000000  28169.000000           0.177226  110000.000000
#
#               P25th          P75th   College_jobs  Non_college_jobs  \
# count    173.000000     173.000000     173.000000        173.000000
# mean   29501.445087   51494.219653   12322.635838      13284.497110
# std     9166.005235   14906.279740   21299.868863      23789.655363
# min    18500.000000   22000.000000       0.000000          0.000000
# 25%    24000.000000   42000.000000    1675.000000       1591.000000
# 50%    27000.000000   47000.000000    4390.000000       4595.000000
# 75%    33000.000000   60000.000000   14444.000000      11783.000000
# max    95000.000000  125000.000000  151643.000000     148395.000000
#
#        Low_wage_jobs
# count     173.000000
# mean     3859.017341
# std      6944.998579
# min         0.000000
# 25%       340.000000
# 50%      1231.000000
# 75%      3466.000000
# max     48207.000000

# %%
raw_data_count = recent_grads.shape[0]
print("Before cleaning:", raw_data_count)
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape[0]
print("After cleaning:", cleaned_data_count)
# Out:
# Before cleaning: 172
# After cleaning: 172

# %% [markdown]
# ## Scatter Plots

# %%
recent_grads.plot(x="Sample_size", y="Median", kind="scatter", title="Sample_size and Median")

# %%
recent_grads.plot(x="Sample_size", y="Unemployment_rate", kind="scatter", title="Sample_size and Unemployment_rate")

# %%
recent_grads.plot(x="Full_time", y="Median", kind="scatter", title="Full_time and Median")

# %%
recent_grads.plot(x="ShareWomen", y="Unemployment_rate", kind="scatter", title="ShareWomen and Unemployment_rate")

# %%
recent_grads.plot(x="Men", y="Median", kind="scatter", title="Men and Median")

# %%
recent_grads.plot(x="Women", y="Median", kind="scatter", title="Women and Median")

# %% [markdown]
# ## Histograms

# %%
columns = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]

fig = plt.figure(figsize=(10,35))
for i in range(8):
    ax = fig.add_subplot(8,1,i+1)
    ax = recent_grads[columns[i]].hist(bins=20)
    ax.set_title(columns[i])

# %% [markdown]
# ## Scatter Matrix Plots

# %%
from pandas.tools.plotting import scatter_matrix

scatter_matrix(recent_grads[["Sample_size", "Median"]])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1e28314358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1e2828fa58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1e2826e550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1e282e1e10>]], dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size", "Median", "Unemployment_rate"]], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1e23ec1390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1e23a21898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1e23fa04a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1e23cf92b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1e2850ef98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1e280db4a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1e23c190f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1e23bc4ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1e23f50f60>]], dtype=object)

# %% [markdown]
# ## Bar Plots

# %%
recent_grads[:10].plot.bar(x="Major", y="ShareWomen", legent=False)
recent_grads[:10].plot.bar(x="Major", y="Unemployment_rate", legent=False)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-65-bc61dab164a8> in <module>()
# ----> 1 recent_grads[:10].plot.bar(x="Major", y="ShareWomen", legent=False)
#       2 recent_grads[:10].plot.bar(x="Major", y="Unemployment_rate", legent=False)
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/tools/plotting.py in bar(self, x, y, **kwds)
#    3811         axes : matplotlib.AxesSubplot or np.array of them
#    3812         """
# -> 3813         return self(kind='bar', x=x, y=y, **kwds)
#    3814
#    3815     def barh(self, x=None, y=None, **kwds):
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/tools/plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/tools/plotting.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2641                  yerr=yerr, xerr=xerr,
#    2642                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2643                  **kwds)
#    2644
#    2645
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/tools/plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2468         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2469
# -> 2470     plot_obj.generate()
#    2471     plot_obj.draw()
#    2472     return plot_obj.result
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/tools/plotting.py in generate(self)
#    1041         self._compute_plot_data()
#    1042         self._setup_subplots()
# -> 1043         self._make_plot()
#    1044         self._add_table()
#    1045         self._make_legend()
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/tools/plotting.py in _make_plot(self)
#    1997                 rect = self._plot(ax, self.ax_pos + (i + 0.5) * w, y, w,
#    1998                                   start=start, label=label,
# -> 1999                                   log=self.log, **kwds)
#    2000             self._add_legend_handle(rect, label, index=i)
#    2001
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/tools/plotting.py in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1944     @classmethod
#    1945     def _plot(cls, ax, x, y, w, start=0, log=False, **kwds):
# -> 1946         return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#    1947
#    1948     @property
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/matplotlib/axes/_axes.py in bar(self, left, height, width, bottom, **kwargs)
#    2129                 label='_nolegend_'
#    2130                 )
# -> 2131             r.update(kwargs)
#    2132             r.get_path()._interpolation_steps = 100
#    2133             #print r.get_label(), label, 'label' in kwargs
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/matplotlib/artist.py in update(self, props)
#     854                 func = getattr(self, 'set_' + k, None)
#     855                 if func is None or not six.callable(func):
# --> 856                     raise AttributeError('Unknown property %s' % k)
#     857                 func(v)
#     858             changed = True
#
# AttributeError: Unknown property legent
